# %% [markdown]
# # Capstone Project: Battle of the Neighborhoods (Week 2)

# %% [markdown]
# ## Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In this project we will try to find an **optimal location for an art gallery**. Specifically, this report will be targeted to stakeholders interested in opening an **art gallery in Paris, France**.
#
# Since there are lots of art galleries in Paris we will try to detect locations that are not already crowded with art galleries. We are also particularly interested in areas with no sculpture galleries in vicinity. We would also prefer locations as close to the city centre.
#
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
# * number of existing art galleries in the neighborhood
# * distance of neighborhood from city center
#
# We decided to use regularly spaced grid of locations, centered around city center, to define our neighborhoods.
#
# Following data sources will be needed to extract/generate the required information:
# * mapping and consolidation of location data features will be done using **Folium**
# * number of art galleries and their type and location in every neighborhood will be obtained using **Foursquare API**

# %% [markdown]
# We start by importing the necessary libraries.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0           conda-forge
#     geopy:           1.22.0-pyh9f0ad1d_0 conda-forge
#     python_abi:      3.6-1_cp36m         conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                      --> 2020.4.5.1-hecc5488_0     conda-forge
#     certifi:         2020.4.5.1-py36_0               --> 2020.4.5.1-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0               --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# ca-certificates-2020 | 146 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# certifi-2020.4.5.1   | 151 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# First we get the latitude & longitude coordinates for centroids of the key locations. We will create a grid of cells covering our area of interest which is aprox. 10x10 killometers centered around the Louvre museum.
#
# The first step is finding the latitude & longitude of the Louvre museum, using its address - Rue de Rivoli, 75001 Paris - and the Foursquare API.

# %%
address = 'Rue de Rivoli, Paris, France'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
 
print("Coordinates of Louvre:",latitude, longitude)
# Out:
# Coordinates of Louvre: 48.866387 2.3234711

# %%
search_query = 'art gallery'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# art gallery .... OK!

# %%
url='https://api.foursquare.com/v2/venues/search?client_id=ALDAVZA23BVAYDJ55UWNZYDVYGHPXQCQKHJM1ZWYKWORJAKC&client_secret=2W4BBJS51LIRUNZAYG5CTRPX5WR55RVVLEWZ1FRNZ2GM1B1G&v=20200606&ll=48.866387,2.3234711&query=artgallery&radius=5000&limit=1000'
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ALDAVZA23BVAYDJ55UWNZYDVYGHPXQCQKHJM1ZWYKWORJAKC&client_secret=2W4BBJS51LIRUNZAYG5CTRPX5WR55RVVLEWZ1FRNZ2GM1B1G&v=20200606&ll=48.866387,2.3234711&query=artgallery&radius=5000&limit=1000'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5edced400a2972001b740882'},
#  'response': {'venues': [{'id': '4cab440436fa6dcb2f6cd778',
#     'name': "Galerie d'Art Primitif Africain        Art Gallery l'Oeil et la Main     Expert",
#     'location': {'address': '41 rue de Verneuil',
#      'lat': 48.857997,
#      'lng': 2.328082,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.857997,
#        'lng': 2.328082}],
#      'distance': 993,
#      'postalCode': '75007',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['41 rue de Verneuil', '75007 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '54632235'},
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '4c9b951680958cfa47fe4cd4',
#     'name': 'Art Concorde',
#     'location': {'address': '36 rue de Penthièvre',
#      'lat': 48.87225903355606,
#      'lng': 2.313297986984253,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.87225903355606,
#        'lng': 2.313297986984253}],
#      'distance': 991,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['36 rue de Penthièvre', '75008 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '5236fcf2498e2893fd02b918',
#     'name': 'Bolotina Art Gallery',
#     'location': {'address': '21 rue',
#      'lat': 48.866325872916626,
#      'lng': 2.334102157444136,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.866325872916626,
#        'lng': 2.334102157444136}],
#      'distance': 778,
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['21 rue', 'Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '50ae6a6be4b0bcea5ca90981',
#     'name': 'BJ Art Gallery',
#     'location': {'address': '45 rue de Penthièvre',
#      'lat': 48.87227,
#      'lng': 2.313395,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.87227,
#        'lng': 2.313395}],
#      'distance': 986,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['45 rue de Penthièvre', '75008 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '533720c9498e8f2e48cc9e5f',
#     'name': 'Prince &  Princess Art Gallery',
#     'location': {'address': '96 rue de Grenelle',
#      'lat': 48.85599899291992,
#      'lng': 2.3226711750030518,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85599899291992,
#        'lng': 2.3226711750030518}],
#      'distance': 1157,
#      'postalCode': '75007',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['96 rue de Grenelle', '75007 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '4c194296838020a13a72e561',
#     'name': 'Alwane Art Gallery',
#     'location': {'address': '8 rue Milton',
#      'lat': 48.87732378451565,
#      'lng': 2.3407933115959163,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.87732378451565,
#        'lng': 2.3407933115959163}],
#      'distance': 1758,
#      'postalCode': '75009',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['8 rue Milton', '75009 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '57e15202498eee71d3f97f8a',
#     'name': 'A2Z Art Gallery',
#     'location': {'address': "24 rue de l'Échaudé",
#      'lat': 48.853578,
#      'lng': 2.335615,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.853578,
#        'lng': 2.335615}],
#      'distance': 1680,
#      'postalCode': '75006',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ["24 rue de l'Échaudé", '75006 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '57b6ea0c498e3f2ad319159c',
#     'name': 'Paris Art Gallery',
#     'location': {'address': '67 avenue de Breteuil',
#      'lat': 48.847894,
#      'lng': 2.312242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.847894,
#        'lng': 2.312242}],
#      'distance': 2216,
#      'postalCode': '75007',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['67 avenue de Breteuil', '75007 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '327292616'},
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '55e88e33498e4f14ce62c7d7',
#     'name': 'In)( between Art Gallery',
#     'location': {'address': '39 rue Chapon',
#      'lat': 48.8657,
#      'lng': 2.3534,
#      'labeledLatLngs': [{'label': 'display', 'lat': 48.8657, 'lng': 2.3534}],
#      'distance': 2192,
#      'postalCode': '75003',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['39 rue Chapon', '75003 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '55e2650b498e2abd1bc307bb',
#     'name': 'International Art Gallery',
#     'location': {'address': '78 avenue de Suffren',
#      'lat': 48.8519123,
#      'lng': 2.2995903,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.8519123,
#        'lng': 2.2995903}],
#      'distance': 2378,
#      'postalCode': '75015',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['78 avenue de Suffren', '75015 Paris', 'France']},
#     'categories': [],
#     'venuePage': {'id': '142412727'},
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '4c629f9f4b5176b033d20517',
#     'name': 'Democratik-art Gallery',
#     'location': {'address': '17 rue François Miron',
#      'lat': 48.85564530114246,
#      'lng': 2.3571702088984767,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85564530114246,
#        'lng': 2.3571702088984767}],
#      'distance': 2742,
#      'postalCode': '75004',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['17 rue François Miron', '75004 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '55b122dd498e7e70c616cf67',
#     'name': 'French Paper Art Gallery',
#     'location': {'address': '51 rue Volta',
#      'lat': 48.867194,
#      'lng': 2.358324,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.867194,
#        'lng': 2.358324}],
#      'distance': 2553,
#      'postalCode': '75003',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['51 rue Volta', '75003 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '4f6927eee4b07dcd55ac70a4',
#     'name': "No Man's Art Gallery",
#     'location': {'lat': 48.86184285488514,
#      'lng': 2.3645111573469877,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86184285488514,
#        'lng': 2.3645111573469877}],
#      'distance': 3047,
#      'cc': 'FR',
#      'country': 'France',
#      'formattedAddress': ['France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '519cf821498e2470b94d61b2',
#     'name': 'In)(between Art Gallery',
#     'location': {'address': '3 Rue Saint Anastase',
#      'lat': 48.85952815161378,
#      'lng': 2.3642139204759096,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85952815161378,
#        'lng': 2.3642139204759096}],
#      'distance': 3079,
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['3 Rue Saint Anastase', 'Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '50125b15c84c561e8cb6eb54',
#     'name': 'Lowave - art gallery',
#     'location': {'address': '8, rue Alphonse Baudin',
#      'lat': 48.860472814839454,
#      'lng': 2.3709869384765625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.860472814839454,
#        'lng': 2.3709869384765625}],
#      'distance': 3541,
#      'postalCode': '75011',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['8, rue Alphonse Baudin', '75011 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '55118363498e75ba7458679d',
#     'name': 'printmodel art gallery',
#     'location': {'lat': 48.84551,
#      'lng': 2.378723,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.84551,
#        'lng': 2.378723}],
#      'distance': 4666,
#      'cc': 'FR',
#      'country': 'France',
#      'formattedAddress': ['France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591537148',
#     'hasPerk': False},
#    {'id': '53270325498eb8b519cd77ff',
#     'name': 'Joel Knafo Art Gallery',
#     'location': {'address': '146, boulevard Vincent Auriol',
#      'lat': 48.83269515561537,
#      'lng': 2.3599620415245233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.83269515561537,
#        'lng': 2.3599620415245233}],
#      'distance': 4605,
#      'postalCode': '75013',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['146, boulevard Vincent Auriol',
#       '75013 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '86359867'},
#     'referralId': 'v-1591537148',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
# 3  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
# 4  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
#
#                          id      location.address location.cc location.city  \
# 0  4cab440436fa6dcb2f6cd778    41 rue de Verneuil          FR         Paris
# 1  4c9b951680958cfa47fe4cd4  36 rue de Penthièvre          FR         Paris
# 2  5236fcf2498e2893fd02b918                21 rue          FR         Paris
# 3  50ae6a6be4b0bcea5ca90981  45 rue de Penthièvre          FR         Paris
# 4  533720c9498e8f2e48cc9e5f    96 rue de Grenelle          FR         Paris
#
#   location.country  location.distance  \
# 0           France                993
# 1           France                991
# 2           France                778
# 3           France                986
# 4           France               1157
#
#                      location.formattedAddress  \
# 0    [41 rue de Verneuil, 75007 Paris, France]
# 1  [36 rue de Penthièvre, 75008 Paris, France]
# 2                      [21 rue, Paris, France]
# 3  [45 rue de Penthièvre, 75008 Paris, France]
# 4    [96 rue de Grenelle, 75007 Paris, France]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 48.857997, 'lng':...     48.857997
# 1  [{'label': 'display', 'lat': 48.87225903355606...     48.872259
# 2  [{'label': 'display', 'lat': 48.86632587291662...     48.866326
# 3  [{'label': 'display', 'lat': 48.87227, 'lng': ...     48.872270
# 4  [{'label': 'display', 'lat': 48.85599899291992...     48.855999
#
#    location.lng location.postalCode location.state  \
# 0      2.328082               75007  Île-de-France
# 1      2.313298               75008  Île-de-France
# 2      2.334102                 NaN  Île-de-France
# 3      2.313395               75008  Île-de-France
# 4      2.322671               75007  Île-de-France
#
#                                                 name    referralId  \
# 0  Galerie d'Art Primitif Africain        Art Gal...  v-1591537148
# 1                                       Art Concorde  v-1591537148
# 2                               Bolotina Art Gallery  v-1591537148
# 3                                     BJ Art Gallery  v-1591537148
# 4                     Prince &  Princess Art Gallery  v-1591537148
#
#   venuePage.id
# 0     54632235
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name   categories  \
# 0   Galerie d'Art Primitif Africain        Art Gal...  Art Gallery
# 1                                        Art Concorde  Art Gallery
# 2                                Bolotina Art Gallery  Art Gallery
# 3                                      BJ Art Gallery  Art Gallery
# 4                      Prince &  Princess Art Gallery  Art Gallery
# 5                                  Alwane Art Gallery  Art Gallery
# 6                                     A2Z Art Gallery  Art Gallery
# 7                                   Paris Art Gallery  Art Gallery
# 8                            In)( between Art Gallery  Art Gallery
# 9                           International Art Gallery         None
# 10                             Democratik-art Gallery  Art Gallery
# 11                           French Paper Art Gallery  Art Gallery
# 12                               No Man's Art Gallery  Art Gallery
# 13                            In)(between Art Gallery  Art Gallery
# 14                               Lowave - art gallery  Art Gallery
# 15                             printmodel art gallery  Art Gallery
# 16                             Joel Knafo Art Gallery  Art Gallery
#
#                           address  cc   city country  distance  \
# 0              41 rue de Verneuil  FR  Paris  France       993
# 1            36 rue de Penthièvre  FR  Paris  France       991
# 2                          21 rue  FR  Paris  France       778
# 3            45 rue de Penthièvre  FR  Paris  France       986
# 4              96 rue de Grenelle  FR  Paris  France      1157
# 5                    8 rue Milton  FR  Paris  France      1758
# 6             24 rue de l'Échaudé  FR  Paris  France      1680
# 7           67 avenue de Breteuil  FR  Paris  France      2216
# 8                   39 rue Chapon  FR  Paris  France      2192
# 9            78 avenue de Suffren  FR  Paris  France      2378
# 10          17 rue François Miron  FR  Paris  France      2742
# 11                   51 rue Volta  FR  Paris  France      2553
# 12                            NaN  FR    NaN  France      3047
# 13           3 Rue Saint Anastase  FR  Paris  France      3079
# 14         8, rue Alphonse Baudin  FR  Paris  France      3541
# 15                            NaN  FR    NaN  France      4666
# 16  146, boulevard Vincent Auriol  FR  Paris  France      4605
#
#                                      formattedAddress  \
# 0           [41 rue de Verneuil, 75007 Paris, France]
# 1         [36 rue de Penthièvre, 75008 Paris, France]
# 2                             [21 rue, Paris, France]
# 3         [45 rue de Penthièvre, 75008 Paris, France]
# 4           [96 rue de Grenelle, 75007 Paris, France]
# 5                 [8 rue Milton, 75009 Paris, France]
# 6          [24 rue de l'Échaudé, 75006 Paris, France]
# 7        [67 avenue de Breteuil, 75007 Paris, France]
# 8                [39 rue Chapon, 75003 Paris, France]
# 9         [78 avenue de Suffren, 75015 Paris, France]
# 10       [17 rue François Miron, 75004 Paris, France]
# 11                [51 rue Volta, 75003 Paris, France]
# 12                                           [France]
# 13              [3 Rue Saint Anastase, Paris, France]
# 14      [8, rue Alphonse Baudin, 75011 Paris, France]
# 15                                           [France]
# 16  [146, boulevard Vincent Auriol, 75013 Paris, F...
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 48.857997, 'lng':...  48.857997  2.328082
# 1   [{'label': 'display', 'lat': 48.87225903355606...  48.872259  2.313298
# 2   [{'label': 'display', 'lat': 48.86632587291662...  48.866326  2.334102
# 3   [{'label': 'display', 'lat': 48.87227, 'lng': ...  48.872270  2.313395
# 4   [{'label': 'display', 'lat': 48.85599899291992...  48.855999  2.322671
# 5   [{'label': 'display', 'lat': 48.87732378451565...  48.877324  2.340793
# 6   [{'label': 'display', 'lat': 48.853578, 'lng':...  48.853578  2.335615
# 7   [{'label': 'display', 'lat': 48.847894, 'lng':...  48.847894  2.312242
# 8   [{'label': 'display', 'lat': 48.8657, 'lng': 2...  48.865700  2.353400
# 9   [{'label': 'display', 'lat': 48.8519123, 'lng'...  48.851912  2.299590
# 10  [{'label': 'display', 'lat': 48.85564530114246...  48.855645  2.357170
# 11  [{'label': 'display', 'lat': 48.867194, 'lng':...  48.867194  2.358324
# 12  [{'label': 'display', 'lat': 48.86184285488514...  48.861843  2.364511
# 13  [{'label': 'display', 'lat': 48.85952815161378...  48.859528  2.364214
# 14  [{'label': 'display', 'lat': 48.86047281483945...  48.860473  2.370987
# 15  [{'label': 'display', 'lat': 48.84551, 'lng': ...  48.845510  2.378723
# 16  [{'label': 'display', 'lat': 48.83269515561537...  48.832695  2.359962
#
#    postalCode          state                        id
# 0       75007  Île-de-France  4cab440436fa6dcb2f6cd778
# 1       75008  Île-de-France  4c9b951680958cfa47fe4cd4
# 2         NaN  Île-de-France  5236fcf2498e2893fd02b918
# 3       75008  Île-de-France  50ae6a6be4b0bcea5ca90981
# 4       75007  Île-de-France  533720c9498e8f2e48cc9e5f
# 5       75009  Île-de-France  4c194296838020a13a72e561
# 6       75006  Île-de-France  57e15202498eee71d3f97f8a
# 7       75007  Île-de-France  57b6ea0c498e3f2ad319159c
# 8       75003  Île-de-France  55e88e33498e4f14ce62c7d7
# 9       75015  Île-de-France  55e2650b498e2abd1bc307bb
# 10      75004  Île-de-France  4c629f9f4b5176b033d20517
# 11      75003  Île-de-France  55b122dd498e7e70c616cf67
# 12        NaN            NaN  4f6927eee4b07dcd55ac70a4
# 13        NaN  Île-de-France  519cf821498e2470b94d61b2
# 14      75011  Île-de-France  50125b15c84c561e8cb6eb54
# 15        NaN            NaN  55118363498e75ba7458679d
# 16      75013  Île-de-France  53270325498eb8b519cd77ff

# %%
dataframe_filtered.name
# Out:
# 0     Galerie d'Art Primitif Africain        Art Gal...
# 1                                          Art Concorde
# 2                                  Bolotina Art Gallery
# 3                                        BJ Art Gallery
# 4                        Prince &  Princess Art Gallery
# 5                                    Alwane Art Gallery
# 6                                       A2Z Art Gallery
# 7                                     Paris Art Gallery
# 8                              In)( between Art Gallery
# 9                             International Art Gallery
# 10                               Democratik-art Gallery
# 11                             French Paper Art Gallery
# 12                                 No Man's Art Gallery
# 13                              In)(between Art Gallery
# 14                                 Lowave - art gallery
# 15                               printmodel art gallery
# 16                               Joel Knafo Art Gallery
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Louvre

# add a red circle marker to represent the Louvre
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Louvre',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the art galleries as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# So now we have all the art galleries in area within few kilometers from the Louvre!
# This concludes the data gathering phase - we're now ready to use this data for analysis to produce the report on optimal locations for a new art gallery!

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this project we will direct our efforts on detecting areas of Paris that have low restaurant density, particularly those with low number of Italian restaurants. We will limit our analysis to area ~5km around city center.
# In first step we have collected the required data: location of every art gallery within 5km from Paris center. We identify the Paris center to be the area around the Louvre museum(also called the 1st Arrondissement). We believe that this is the optimal centerpoint because it is where the majority of tourists spend most of their time. This is of particular interest for the stakeholders since it increases their chances of maximizing their revenue.
#
# Second step in our analysis will be calculation and exploration of 'art gallery density' across different areas of Paris - we will use heatmaps to identify a few promising areas close to center with low number of art galleries in general and focus our attention on those areas.
#
# In third and final step we will focus on most promising areas and within those create clusters of locations that meet some basic requirements established in discussion with stakeholders: we will take into consideration locations with no more than three restaurants in radius of 300 meters. We will present map of all such locations but also create clusters (using k-means clustering) of those locations to identify general zones / neighborhoods / addresses which should be a starting point for final 'street level' exploration and search for optimal venue location by stakeholders.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Let's perform some basic explanatory data analysis and derive some additional info from our raw data. First let's count the number of art galleries in every area candidate:

# %%
location_count = [len(dataframe_filtered)]
print('Average number of art galleries in every area with radius=300m:', np.array(location_count).mean())
dataframe_filtered
# Out:
# Average number of art galleries in every area with radius=300m: 17.0
#                                                  name   categories  \
# 0   Galerie d'Art Primitif Africain        Art Gal...  Art Gallery
# 1                                        Art Concorde  Art Gallery
# 2                                Bolotina Art Gallery  Art Gallery
# 3                                      BJ Art Gallery  Art Gallery
# 4                      Prince &  Princess Art Gallery  Art Gallery
# 5                                  Alwane Art Gallery  Art Gallery
# 6                                     A2Z Art Gallery  Art Gallery
# 7                                   Paris Art Gallery  Art Gallery
# 8                            In)( between Art Gallery  Art Gallery
# 9                           International Art Gallery         None
# 10                             Democratik-art Gallery  Art Gallery
# 11                           French Paper Art Gallery  Art Gallery
# 12                               No Man's Art Gallery  Art Gallery
# 13                            In)(between Art Gallery  Art Gallery
# 14                               Lowave - art gallery  Art Gallery
# 15                             printmodel art gallery  Art Gallery
# 16                             Joel Knafo Art Gallery  Art Gallery
#
#                           address  cc   city country  distance  \
# 0              41 rue de Verneuil  FR  Paris  France       993
# 1            36 rue de Penthièvre  FR  Paris  France       991
# 2                          21 rue  FR  Paris  France       778
# 3            45 rue de Penthièvre  FR  Paris  France       986
# 4              96 rue de Grenelle  FR  Paris  France      1157
# 5                    8 rue Milton  FR  Paris  France      1758
# 6             24 rue de l'Échaudé  FR  Paris  France      1680
# 7           67 avenue de Breteuil  FR  Paris  France      2216
# 8                   39 rue Chapon  FR  Paris  France      2192
# 9            78 avenue de Suffren  FR  Paris  France      2378
# 10          17 rue François Miron  FR  Paris  France      2742
# 11                   51 rue Volta  FR  Paris  France      2553
# 12                            NaN  FR    NaN  France      3047
# 13           3 Rue Saint Anastase  FR  Paris  France      3079
# 14         8, rue Alphonse Baudin  FR  Paris  France      3541
# 15                            NaN  FR    NaN  France      4666
# 16  146, boulevard Vincent Auriol  FR  Paris  France      4605
#
#                                      formattedAddress  \
# 0           [41 rue de Verneuil, 75007 Paris, France]
# 1         [36 rue de Penthièvre, 75008 Paris, France]
# 2                             [21 rue, Paris, France]
# 3         [45 rue de Penthièvre, 75008 Paris, France]
# 4           [96 rue de Grenelle, 75007 Paris, France]
# 5                 [8 rue Milton, 75009 Paris, France]
# 6          [24 rue de l'Échaudé, 75006 Paris, France]
# 7        [67 avenue de Breteuil, 75007 Paris, France]
# 8                [39 rue Chapon, 75003 Paris, France]
# 9         [78 avenue de Suffren, 75015 Paris, France]
# 10       [17 rue François Miron, 75004 Paris, France]
# 11                [51 rue Volta, 75003 Paris, France]
# 12                                           [France]
# 13              [3 Rue Saint Anastase, Paris, France]
# 14      [8, rue Alphonse Baudin, 75011 Paris, France]
# 15                                           [France]
# 16  [146, boulevard Vincent Auriol, 75013 Paris, F...
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 48.857997, 'lng':...  48.857997  2.328082
# 1   [{'label': 'display', 'lat': 48.87225903355606...  48.872259  2.313298
# 2   [{'label': 'display', 'lat': 48.86632587291662...  48.866326  2.334102
# 3   [{'label': 'display', 'lat': 48.87227, 'lng': ...  48.872270  2.313395
# 4   [{'label': 'display', 'lat': 48.85599899291992...  48.855999  2.322671
# 5   [{'label': 'display', 'lat': 48.87732378451565...  48.877324  2.340793
# 6   [{'label': 'display', 'lat': 48.853578, 'lng':...  48.853578  2.335615
# 7   [{'label': 'display', 'lat': 48.847894, 'lng':...  48.847894  2.312242
# 8   [{'label': 'display', 'lat': 48.8657, 'lng': 2...  48.865700  2.353400
# 9   [{'label': 'display', 'lat': 48.8519123, 'lng'...  48.851912  2.299590
# 10  [{'label': 'display', 'lat': 48.85564530114246...  48.855645  2.357170
# 11  [{'label': 'display', 'lat': 48.867194, 'lng':...  48.867194  2.358324
# 12  [{'label': 'display', 'lat': 48.86184285488514...  48.861843  2.364511
# 13  [{'label': 'display', 'lat': 48.85952815161378...  48.859528  2.364214
# 14  [{'label': 'display', 'lat': 48.86047281483945...  48.860473  2.370987
# 15  [{'label': 'display', 'lat': 48.84551, 'lng': ...  48.845510  2.378723
# 16  [{'label': 'display', 'lat': 48.83269515561537...  48.832695  2.359962
#
#    postalCode          state                        id
# 0       75007  Île-de-France  4cab440436fa6dcb2f6cd778
# 1       75008  Île-de-France  4c9b951680958cfa47fe4cd4
# 2         NaN  Île-de-France  5236fcf2498e2893fd02b918
# 3       75008  Île-de-France  50ae6a6be4b0bcea5ca90981
# 4       75007  Île-de-France  533720c9498e8f2e48cc9e5f
# 5       75009  Île-de-France  4c194296838020a13a72e561
# 6       75006  Île-de-France  57e15202498eee71d3f97f8a
# 7       75007  Île-de-France  57b6ea0c498e3f2ad319159c
# 8       75003  Île-de-France  55e88e33498e4f14ce62c7d7
# 9       75015  Île-de-France  55e2650b498e2abd1bc307bb
# 10      75004  Île-de-France  4c629f9f4b5176b033d20517
# 11      75003  Île-de-France  55b122dd498e7e70c616cf67
# 12        NaN            NaN  4f6927eee4b07dcd55ac70a4
# 13        NaN  Île-de-France  519cf821498e2470b94d61b2
# 14      75011  Île-de-France  50125b15c84c561e8cb6eb54
# 15        NaN            NaN  55118363498e75ba7458679d
# 16      75013  Île-de-France  53270325498eb8b519cd77ff

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# We can see that, according to Foursquare data, the small number of art galleries found in the key area (5km within the Louvre) means that our stakeholders will not be faced with overwhelming competition. This is true no matter where they may choose to open their art gallery, since only 17 such galleries exist in the area that concerns them.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# In conclusion, the project has found valuable information for the stakeholders. They had expected a very high number of art galleries to be found in the area most tourists visit when they go to Paris, but instead they found a very low number of competitors.
#
# This means they are likely to be successful in their business.
